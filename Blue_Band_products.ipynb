# %% [markdown]
# <a href="https://colab.research.google.com/github/bonangira/bonangira/blob/main/Blue_Band_products.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Blue Band Sales.csv")

# %%
data.head()
# Out:
#             Starehe  Original  Spread for Bread  Mayonnaise  Peanut Butter  \
# 0    Dagoreti North      4200              3000        2950           2800
# 1    Dagoreti South      4020              3050        3000           2080
# 2     Embakai South      4050              3500        3100           2900
# 3  Embakasi Central      4100              3400        2900           2700
# 4     Embakasi East      4080              3100        3040           2050
#
#    Canola Oil  Baking Margarine  Total Sales
# 0        2650              2760         18360
# 1        2000              1900         16050
# 2        2500              2000         18050
# 3        1800              1900         16800
# 4        2020              1950         16240

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Starehe           17 non-null     object
#  1   Original          17 non-null     int64
#  2   Spread for Bread  17 non-null     int64
#  3   Mayonnaise        17 non-null     int64
#  4   Peanut Butter     17 non-null     int64
#  5   Canola Oil        17 non-null     int64
#  6   Baking Margarine  17 non-null     int64
#  7   Total Sales       17 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.2+ KB

# %%
data.describe()
# Out:
#           Original  Spread for Bread   Mayonnaise  Peanut Butter   Canola Oil  \
# count    17.000000         17.000000    17.000000      17.000000    17.000000
# mean   4151.176471       3318.823529  2878.823529    2803.529412  2262.941176
# std     146.453165        224.774397   257.630607     387.426464   374.796023
# min    3900.000000       3000.000000  2000.000000    2000.000000  1800.000000
# 25%    4050.000000       3150.000000  2800.000000    2800.000000  2000.000000
# 50%    4150.000000       3300.000000  2950.000000    2900.000000  2050.000000
# 75%    4250.000000       3500.000000  3000.000000    3050.000000  2600.000000
# max    4460.000000       3680.000000  3100.000000    3250.000000  3000.000000
#
#        Baking Margarine  Total Sales
# count         17.000000     17.000000
# mean        1894.705882  17310.000000
# std          252.688485    887.454224
# min         1600.000000  15750.000000
# 25%         1800.000000  16800.000000
# ...

# %%
print(data.columns)
# Out:
# Index(['Starehe', 'Original', 'Spread for Bread', 'Mayonnaise',
#        'Peanut Butter', 'Canola Oil', 'Baking Margarine', 'Total Sales '],
#       dtype='object')

# %% [markdown]
# **Relating the variables using scatterplots**

# %%
sns.relplot(x="Original", y="Mayonnaise",data=data)
